# %% [markdown]
# ## Spectral Clustering スペクトラルクラスタリング
# 教師なし分類問題 clustering
#
# ### Basic Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Libraries for Machine Learning

# %%
from sklearn import datasets
from sklearn import cluster
from sklearn import metrics, preprocessing

# %% [markdown]
# ### 1. Data Preparation and 3. Data Shaping

# %%
X, y = datasets.make_moons(n_samples=200, noise=0.05, random_state=0)
sc = preprocessing.StandardScaler()
X_norm = sc.fit_transform(X)
plt.scatter(X_norm[:, 0], X_norm[:, 1], c=y)

# %% [markdown]
# ### 4. Traning Model

# %%
km = cluster.KMeans(n_clusters=2)
km_y = km.fit(X_norm)
plt.scatter(X,　y, c=km_y.labels_)


# spc = cluster.SpectralClustering(n_clusters=2, affinity="nearest_neighbors")
# spc_y = spc.fit(X_norm)
# Out:
#   File "<ipython-input-29-8a6985e03483>", line 3
#     plt.scatter(X,　y, c=km_y.labels_)
#                   　^
# SyntaxError: invalid character in identifier

# %% [markdown]
# ### 5. Evaluating Model

# %%
plt.scatter(X,y, c=km_y.labels_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-61f12e1bace1> in <module>
# ----> 1 plt.scatter(X,y, c=km_y.labels_)
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2862         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2863         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2864         is not None else {}), **kwargs)
#    2865     sci(__ret)
#    2866     return __ret
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1803                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1804                         RuntimeWarning, stacklevel=2)
# -> 1805             return func(ax, *args, **kwargs)
#    1806
#    1807         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4170         y = np.ma.ravel(y)
#    4171         if x.size != y.size:
# -> 4172             raise ValueError("x and y must be the same size")
#    4173
#    4174         if s is None:
#
# ValueError: x and y must be the same size
